# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importación de datos
Data = pd.read_csv("C:/Users/lfvvi/OneDrive/Documentos/ESCRITORIO/DS - SELF LEARNING/MACHINE LEARNING/1. SUPERVISED/3. Decision Trees (DT)/Python/DataSet.csv")

#Análisis descriptivo de los datos
Data.describe(include="all")
# Out:
#        outlook temp. humidity  windy play
# count       14    14       14     14   14
# unique       3     3        2      2    2
# top      sunny  mild     high  False  yes
# freq         6     6        7      8    9

# %%
Data.head(n=14)
# Out:
#      outlook temp. humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3     rainny  mild     high  False  yes
# 4     rainny  cool   normal  False  yes
# 5     rainny  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      sunny  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13    rainny  mild     high   True   no

# %%
plt.figure(figsize=(10, 5))
plt.hist(Data['outlook'])
plt.title("Data")
plt.ylabel("Fec")
plt.show()

# %%
#Se obtienen las categorias o valores unicos de cada una de las columnas de la matriz
Data_Outlook = pd.unique(Data['outlook'])
Data_humidity = pd.unique(Data['humidity'])
Data_windy = pd.unique(Data['windy'])
Data_play = pd.unique(Data['play'])
